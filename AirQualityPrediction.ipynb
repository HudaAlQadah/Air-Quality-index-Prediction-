# %%
# importing pandas module for data frame
import pandas as pd
Urljson ="https://www.data.act.gov.au/resource/94a5-zqnn.json"
data = pd.read_json(Urljson)
print(data)

# %%
# importing pandas module for data frame
import pandas as pd

# loading dataset and storing in train variable
AirQualData=pd.read_csv('Air_Quality_Monitoring_Data.csv')

# display top 5 data
AirQualData.head()
# Out:
#      Name                       GPS                DateTime    NO2  O3_1hr  \
# 0  Monash  (-35.418302, 149.094018)  10/05/2022 03:00:00 PM  0.001   0.022
# 1  Florey    (-35.220606, 149.0435)  23/12/2021 04:00:00 PM    NaN     NaN
# 2   Civic  (-35.285399, 149.131536)  03/11/2021 11:00:00 AM    NaN   0.006
# 3  Monash  (-35.418302, 149.094018)  15/06/2021 04:00:00 PM    NaN     NaN
# 4   Civic  (-35.285307, 149.131579)  02/06/2021 05:00:00 PM    NaN     NaN
#
#    O3_4hr  O3_8hr   CO  PM10 1 hr  PM2.5 1 hr  ...  AQI_CO  AQI_NO2  \
# 0   0.021   0.013  0.0       7.22        1.03  ...     0.0      1.0
# 1   0.034   0.029  NaN      14.80       -1.00  ...     NaN      NaN
# 2     NaN   0.010  NaN        NaN         NaN  ...     NaN      NaN
# 3     NaN     NaN  NaN       0.00        7.10  ...     NaN      NaN
# 4     NaN     NaN  NaN       7.30         NaN  ...     NaN      NaN
#
#    AQI_O3_1hr  AQI_O3_4hr  AQI_O3_8hr  AQI_PM10  AQI_PM2.5  AQI_Site  \
# ...

# %%
AirQualData.describe().T
# Out:
#                count       mean         std    min     25%     50%     75%  \
# NO2         159346.0   0.004590    0.007036   0.00   0.000   0.000   0.010
# O3_1hr      227777.0   0.017086    0.038288  -3.42   0.010   0.020   0.023
# O3_4hr      227998.0   0.017276    0.011403   0.00   0.010   0.020   0.023
# O3_8hr       22900.0   0.017512    0.007483   0.00   0.013   0.018   0.023
# CO          158933.0   0.265014    0.420221   0.00   0.080   0.140   0.300
# PM10 1 hr    35862.0   8.997804    8.255782 -16.10   3.800   7.200  12.000
# PM2.5 1 hr   35446.0   5.530774    7.028091 -22.40   1.500   4.300   7.900
# PM10        230639.0  12.834212   29.392076 -18.00   6.000   9.300  14.000
# PM2.5       197418.0   8.702566   28.780107  -1.70   3.200   5.100   8.100
# AQI_CO      162630.0   2.823526    4.602958   0.00   1.000   2.000   3.000
# AQI_NO2     166661.0   3.840527    5.269128   0.00   0.000   2.000   6.000
# ...

# %% [markdown]
# **Information about each column and about null values for each column**

# %%
print(AirQualData.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239938 entries, 0 to 239937
# Data columns (total 22 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Name        239938 non-null  object
#  1   GPS         239938 non-null  object
#  2   DateTime    239938 non-null  object
#  3   NO2         159346 non-null  float64
#  4   O3_1hr      227777 non-null  float64
#  5   O3_4hr      227998 non-null  float64
#  6   O3_8hr      22900 non-null   float64
#  7   CO          158933 non-null  float64
#  8   PM10 1 hr   35862 non-null   float64
#  9   PM2.5 1 hr  35446 non-null   float64
#  10  PM10        230639 non-null  float64
#  11  PM2.5       197418 non-null  float64
#  12  AQI_CO      162630 non-null  float64
#  13  AQI_NO2     166661 non-null  float64
#  14  AQI_O3_1hr  227329 non-null  float64
#  15  AQI_O3_4hr  227753 non-null  float64
#  16  AQI_O3_8hr  22845 non-null   float64
#  17  AQI_PM10    230612 non-null  float64
# ...

# %% [markdown]
# # Removing the date and time columns

# %%
AirData = AirQualData.drop(['Date', 'Time'], axis = 1)

# %% [markdown]
# # Split the geo variable into separate lat and lon variables

# %%
# Create two lists for the loop results to be placed
lat = []
lon = []

#Removing brackets 
AirData['GPS']=  AirData['GPS'].apply(lambda x: x.replace('(','').replace(')',''))
# For each row in a varible,
for row in AirData['GPS']:
    # Try to,
    try:
        # Split the row by comma and append
        # everything before the comma to lat
        lat.append(row.split(',')[0])
        # Split the row by comma and append
        # everything after the comma to lon
        lon.append(row.split(',')[1])
    # But if you get an error
    except:
        # append a missing value to lat
        lat.append(np.NaN)
        # append a missing value to lon
        lon.append(np.NaN)

# Create two new columns from lat and lon
AirData['latitude'] = lat
AirData['longitude'] = lon

# %%
#Droping GPS Column
AirData = AirData.drop(['GPS'], axis = 1)
AirData.head()
# Out:
#      Name                DateTime    NO2  O3_1hr  O3_4hr  O3_8hr   CO  \
# 0  Monash  10/05/2022 03:00:00 PM  0.001   0.022   0.021   0.013  0.0
# 1  Florey  23/12/2021 04:00:00 PM    NaN     NaN   0.034   0.029  NaN
# 2   Civic  03/11/2021 11:00:00 AM    NaN   0.006     NaN   0.010  NaN
# 3  Monash  15/06/2021 04:00:00 PM    NaN     NaN     NaN     NaN  NaN
# 4   Civic  02/06/2021 05:00:00 PM    NaN     NaN     NaN     NaN  NaN
#
#    PM10 1 hr  PM2.5 1 hr   PM10  ...  AQI_CO  AQI_NO2  AQI_O3_1hr  AQI_O3_4hr  \
# 0       7.22        1.03   1.23  ...     0.0      1.0        22.0        27.0
# 1      14.80       -1.00    NaN  ...     NaN      NaN         NaN        43.0
# 2        NaN         NaN  11.10  ...     NaN      NaN         6.0         NaN
# 3       0.00        7.10  17.10  ...     NaN      NaN         NaN         NaN
# 4       7.30         NaN    NaN  ...     NaN      NaN         NaN         NaN
#
#    AQI_O3_8hr  AQI_PM10  AQI_PM2.5  AQI_Site    latitude    longitude
# ...

# %%
#Renaming Columns

AirData.rename(columns = {'Name':'City'}, inplace = True)


dict = {'Name': 'Location',
        'AQI_CO': 'Address',
        'AQI_NO2': 'Amount',
        'AQI_O3_4hr' : '',
        }
 
# call rename () method
df.rename(columns=dict,
          inplace=True)
 
display(df)

# %% [markdown]
# # Sum Total Nulls

# %%
AirData.isnull().sum()
# Out:
# City               0
# DateTime           0
# NO2            80592
# O3_1hr         12161
# O3_4hr         11940
# O3_8hr        217038
# CO             81005
# PM10 1 hr     204076
# PM2.5 1 hr    204492
# PM10            9299
# PM2.5          42520
# AQI_CO         77308
# AQI_NO2        73277
# AQI_O3_1hr     12609
# AQI_O3_4hr     12185
# AQI_O3_8hr    217093
# AQI_PM10        9326
# AQI_PM2.5      38452
# AQI_Site         963
# latitude           0
# longitude          0
# dtype: int64

# %% [markdown]
# # New Section
